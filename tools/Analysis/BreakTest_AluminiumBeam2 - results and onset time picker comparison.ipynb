# %% [markdown]
# # One measurement

# %% [markdown]
# First let's read in the data for BreakTest_AluminiumBeam measurement.

# %%
from helperfuncs.ReadAEMeas import ReadAEMeas

#file = '../../../Measurements/BreakTest_AluminiumBeam2/results2/2-0.15/collect_150.bin'
file = '../../../Measurements/BreakTest_AluminiumBeam2/results2/2-0.15/collect_20.bin'
#file = '../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/4-1/collect_106.bin'
y, y2, T, fnames, start_time = ReadAEMeas(file)

Fs = 1/T
# Out:
# Module folder added to system path: /home/ubuntu/Marmote/tools/ControlRecord/ControlRecord
# Opening file: ../../../Measurements/BreakTest_AluminiumBeam2/results2/2-0.15/collect_20.bin
# Closed file: ../../../Measurements/BreakTest_AluminiumBeam2/results2/2-0.15/collect_20.bin

# %%
import numpy as np

def removeDC(ys):
    for ii in xrange(len(ys)):
        ys[ii] -= np.mean(ys[ii])
    return ys

def trimlength(ys):
    for ii in xrange(len(ys)):
        ys[ii] = ys[ii][:600]
    return ys

# %%
y = trimlength(removeDC(y))
y2 = trimlength(removeDC(y2))

# %% [markdown]
# ### "Traditional" look at data

# %% [markdown]
# Plot AE data in separate axes.

# %%
from helperfuncs.PlotAEMeas import PlotAEMeas

PlotAEMeas(y2,   y,   None,   None,   T*1e6, x_lim_min=0, x_lim_max=1000, y_lim_min=-1, y_lim_max=1) #, threshold=4915.0/(2**15))

# %% [markdown]
# ### Combined look at data

# %%
from helperfuncs.FunctionDisplayRecording_total import FunctionDisplayRecording_total

FunctionDisplayRecording_total(file)
# Out:
# Opening file: ../../../Measurements/BreakTest_AluminiumBeam2/results2/2-0.15/collect_20.bin
# Closed file: ../../../Measurements/BreakTest_AluminiumBeam2/results2/2-0.15/collect_20.bin

# %% [markdown]
# ### Akaike Information Criterion (AIC) onset time picker

# %% [markdown]
# Channel 1

# %%
from helperfuncs.Onset_AIC import Onset_AIC
from helperfuncs.PlotOnsetTime import PlotOnsetTime

ym = y[0]
onset, dummy, curves = Onset_AIC(ym, T*1e3)

PlotOnsetTime(ym, curves, T*1e3, onset, xlabel='Time [ms]')

# %% [markdown]
# Channel 2

# %%
from helperfuncs.Onset_AIC import Onset_AIC
from helperfuncs.PlotOnsetTime import PlotOnsetTime

ym = y2[0]
onset, dummy, curves = Onset_AIC(ym, T*1e3)

PlotOnsetTime(ym, curves, T*1e3, onset, xlabel='Time [ms]')

# %% [markdown]
# ### Taylor series of $\ln$ method onset time picker

# %% [markdown]
# Channel 1

# %%
from helperfuncs.Onset_Method1 import Onset_Method1
from helperfuncs.Fitnes_lnTaylor import Fitnes_lnTaylor
from helperfuncs.PlotOnsetTime import PlotOnsetTime

ym = y[0]
onset, quality, curves = Onset_Method1(ym, T*1e3, Fitnes_lnTaylor)

PlotOnsetTime(ym, curves, T*1e3, onset, xlabel='Time [ms]')

# %% [markdown]
# Channel 2

# %%
from helperfuncs.Onset_Method1 import Onset_Method1
from helperfuncs.Fitnes_lnTaylor import Fitnes_lnTaylor
from helperfuncs.PlotOnsetTime import PlotOnsetTime

ym = y2[0]
onset, quality, curves = Onset_Method1(ym, T*1e3, Fitnes_lnTaylor)

PlotOnsetTime(ym, curves, T*1e3, onset, xlabel='Time [ms]')

# %% [markdown]
# ### Power method onset time picker

# %% [markdown]
# Channel 1

# %%
from helperfuncs.Onset_Method1 import Onset_Method1
from helperfuncs.Fitnes_Power import Fitnes_Power
from helperfuncs.PlotOnsetTime import PlotOnsetTime

ym = y[0]
onset, quality, curves = Onset_Method1(ym, T*1e3, Fitnes_Power)

PlotOnsetTime(ym, curves, T*1e3, onset, xlabel='Time [ms]')

# %% [markdown]
# Channel 2

# %%
from helperfuncs.Onset_Method1 import Onset_Method1
from helperfuncs.Fitnes_Power import Fitnes_Power
from helperfuncs.PlotOnsetTime import PlotOnsetTime

ym = y2[0]
onset, quality, curves = Onset_Method1(ym, T*1e3, Fitnes_Power)

PlotOnsetTime(ym, curves, T*1e3, onset, xlabel='Time [ms]')

# %% [markdown]
# ### Reciprocal method onset time picker

# %% [markdown]
# Channel 1

# %%
from helperfuncs.Onset_Reciprocal import Onset_Reciprocal
from helperfuncs.PlotOnsetTime import PlotOnsetTime

ym = y[0]
onset, dummy, curves = Onset_Reciprocal(ym, T*1e3)

PlotOnsetTime(ym, curves, T*1e3, onset, xlabel='Time [ms]')

# %% [markdown]
# Channel 2

# %%
from helperfuncs.Onset_Reciprocal import Onset_Reciprocal
from helperfuncs.PlotOnsetTime import PlotOnsetTime

ym = y2[0]
onset, dummy, curves = Onset_Reciprocal(ym, T*1e3)

PlotOnsetTime(ym, curves, T*1e3, onset, xlabel='Time [ms]')

# %%
from helperfuncs.Onset_Reciprocal import Onset_Reciprocal
from helperfuncs.PlotOnsetTime import PlotOnsetTime

mu, sigma = 0, 1
ym = mu + sigma*np.random.randn(ym.size)
#ym[320] = 15
onset, dummy, curves = Onset_Reciprocal(ym, T*1e3)

PlotOnsetTime(ym, curves, T*1e3, onset, xlabel='Time [ms]')
