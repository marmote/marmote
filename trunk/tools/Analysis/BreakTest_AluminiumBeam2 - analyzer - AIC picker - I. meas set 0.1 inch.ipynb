# %% [markdown]
# # Read in preprocessed raw data

# %% [markdown]
# First let's read in the data from BreakTest_AluminiumBeam measurement. Note that the threshold filter has already filtered out the frames with signals in them.

# %%
from helperfuncs.ReadAEMeas import ReadAEMeas

dir = '../../../Measurements/BreakTest_AluminiumBeam2/results2/1-0.1'
y, y2, T, fnames, start_time = ReadAEMeas(dir)

Fs = 1/T
#print Fs
# Out:
# Module folder added to system path: /home/ubuntu/Marmote/tools/ControlRecord/ControlRecord
# Opening file: ../../../Measurements/BreakTest_AluminiumBeam2/results2/1-0.1/collect_0.bin
# Closed file: ../../../Measurements/BreakTest_AluminiumBeam2/results2/1-0.1/collect_0.bin
# Opening file: ../../../Measurements/BreakTest_AluminiumBeam2/results2/1-0.1/collect_1.bin
# Closed file: ../../../Measurements/BreakTest_AluminiumBeam2/results2/1-0.1/collect_1.bin
# Opening file: ../../../Measurements/BreakTest_AluminiumBeam2/results2/1-0.1/collect_2.bin
# Closed file: ../../../Measurements/BreakTest_AluminiumBeam2/results2/1-0.1/collect_2.bin
# Opening file: ../../../Measurements/BreakTest_AluminiumBeam2/results2/1-0.1/collect_3.bin
# Closed file: ../../../Measurements/BreakTest_AluminiumBeam2/results2/1-0.1/collect_3.bin
# Opening file: ../../../Measurements/BreakTest_AluminiumBeam2/results2/1-0.1/collect_4.bin
# ...

# %%
import numpy as np

def removeDC(ys):
    for ii in xrange(len(ys)):
        ys[ii] -= np.mean(ys[ii])
    return ys

def trimlength(ys):
    for ii in xrange(len(ys)):
        ys[ii] = ys[ii][:1000]
    return ys

# %%
y = trimlength(removeDC(y))
y2 = trimlength(removeDC(y2))

# %% [markdown]
# # Time Difference of Arrival (TDOA)

# %% [markdown]
# Theoretical value of TD.

# %%
v = 3909.49 #m/s - sound speed in aluminium
dist_diff = (35.5-17.3)*0.0254 #m - distance difference of sensors

TD = dist_diff/v #s - theoretical TD
print 'Theoretical time difference: %.2f us' % (TD*1000000)
#print 'Distance traveled in 810.7 usec: %.2f m' % (810.7e-6*v)
# Out:
# Theoretical time difference: 118.25 us

# %% [markdown]
# ## Akaike Information Criterion (AIC)

# %% [markdown]
# Calculate TDOA using the Akaike Information Criterion (AIC) as onset picker.

# %%
from helperfuncs.CalculateTDOA import CalculateTDOA
from helperfuncs.Onset_AIC import Onset_AIC

AE_start, AE_start2, TD_meas, qty1, qty2 = CalculateTDOA(y, y2, T, Onset_AIC)
qty_min = np.minimum(qty1, qty2)
qty_max = np.maximum(qty1, qty2)
# Out:
# 0.00%
# 8.33%
# 16.67%
# 25.00%
# 33.33%
# 41.67%
# 50.00%
# 58.33%
# 66.67%
# 75.00%
# 83.33%
# 91.67%

# %% [markdown]
# # Time history

# %%
print 'From %.2f to %.2f, altogether %.2f sec.' % (start_time[0], start_time[-1], start_time[-1]-start_time[0])
# Out:
# From 1362.60 to 1887.58, altogether 524.98 sec.

# %%
from helperfuncs.PlotHistory import PlotHistory

PlotHistory(qty_min, 0, qty_max, TD_meas, -1, 1, start_time, 0, start_time[-1]-start_time[0], 0, 30, "Measurements\nmin and max quality idx")
PlotHistory(qty2, 0, qty1, TD_meas, -1, 1, start_time, 0, start_time[-1]-start_time[0], 0, 30, "Measurements\nchannel 1 and 2 quality idx")

# %%
from helperfuncs.PlotHistory import PlotHistory

PlotHistory(qty_min, 0, qty_max, TD_meas, -1, 1, start_time, 0, start_time[-1]-start_time[0], 0, 30, "Measurements\nmin and max quality idx")
PlotHistory(qty_min, 0, qty_max, TD_meas, -0.14e-3, -0.06e-3, start_time, 0, start_time[-1]-start_time[0], 0, 30, "Measurements\nmin and max quality idx for -0.14<TD<-0.06")
#PlotHistory(qty_min, 0, qty_max, TD_meas, 0.06e-3, 0.14e-3, start_time, 0, start_time[-1]-start_time[0], 0, 40, "Measurements\nmin and max quality idx for 0.06<TD<0.14")

# %% [markdown]
# # GMM model estimate with EM

# %% [markdown]
# ## 1D: TD

# %%
from helperfuncs.PlotTDHist import PlotTDHist

PlotTDHist(TD_meas*1e3, fitcurve=False, x_lim_min=-0.3, x_lim_max=0.5, alpha=None, mu=None, sigma=None)

# %%
from helperfuncs.GMM_estimate_EM import GMM_estimate_EM
import numpy as np

alpha_1, mu_1, sigma_1 = GMM_estimate_EM(TD_meas*1e3, alpha = np.array([1.0, 1.0]), mu = np.array([-0.14, 0.1]), sigma = np.array([[[0.005, 0.5]]]))
mu_1 = mu_1.flatten()
sigma_1 = np.sqrt(sigma_1.flatten())
# Out:
# Iterations left: 10
# alpha:
# [ 0.75763975  0.24236025]
# mu:
# [[-0.15167567]
#  [ 0.20320515]]
# sigma:
# [[[ 0.00047489  0.06092747]]]
# Likelihood: 19.10
# change: 57.97%
# Iterations left: 10
# alpha:
# [ 0.816257  0.183743]
# mu:
# [[-0.15196604]
#  [ 0.31770832]]
# sigma:
# [[[ 0.0004672   0.02604299]]]
# Likelihood: 20.18
# change: 5.34%
# Iterations left: 10
# alpha:
# [ 0.832366  0.167634]
# mu:
# [[-0.15175848]
#  [ 0.36181166]]
# sigma:
# [[[ 0.00047631  0.00628002]]]
# Likelihood: 21.09
# change: 4.34%
# Iterations left: 10
# alpha:
# [ 0.83333333  0.16666667]
# mu:
# [[-0.15173333]
#  [ 0.36466666]]
# sigma:
# [[[ 0.00047708  0.0049    ]]]
# Likelihood: 21.12
# change: 0.14%

# %%
from helperfuncs.PlotTDHist import PlotTDHist

PlotTDHist(TD_meas*1e3, fitcurve=True, x_lim_min=-0.3, x_lim_max=0.5, alpha=alpha_1, mu=mu_1, sigma=sigma_1)

# %%
import numpy as np

pickbest = 5
TD_meas_p = (np.array(TD_meas)[np.argsort(qty_min)])[-pickbest:]
alpha_1p, mu_1p, sigma_1p = GMM_estimate_EM(TD_meas_p*1e3, alpha = np.array([1.0]), mu = np.array([-0.14]), sigma = np.array([[[0.005]]]))
mu_1p = mu_1p.flatten()
sigma_1p = np.sqrt(sigma_1p.flatten())
# Out:
# Iterations left: 10
# alpha:
# [ 1.]
# mu:
# [[-0.15706667]]
# sigma:
# [[[ 0.00041344]]]
# Likelihood: 12.38
# change: 32.98%
# Iterations left: 10
# alpha:
# [ 1.]
# mu:
# [[-0.15706667]]
# sigma:
# [[[ 0.00041344]]]
# Likelihood: 12.38
# change: 0.00%

# %%
from helperfuncs.PlotTDHist import PlotTDHist

PlotTDHist(TD_meas_p*1e3, fitcurve=True, x_lim_min=-0.3, x_lim_max=0.0, alpha=alpha_1p, mu=mu_1p, sigma=sigma_1p)

# %% [markdown]
# ## 2D: TD and quality idx

# %%
from helperfuncs.GMM_estimate_EM import GMM_estimate_EM
import numpy as np

alpha0 = np.array([1.0, 1.0])
mu0 = np.array([ [-0.14, 1.0], [0.4, -0.5] ])
sigma0 = np.array( [[[0.005, 0.5],[0.0, 0.0]], [[0.0, 0.0],[0.005, 0.5]]] )
x1 = TD_meas*1e3
x2 = np.log10(qty_min)
x = np.concatenate((np.reshape(x1, (x1.shape[0],-1)),np.reshape(x2, (x2.shape[0],-1))), axis=1)

alpha_1, mu_1, sigma_1 = GMM_estimate_EM( x, alpha = alpha0, mu = mu0, sigma = sigma0 )
# Out:
# Iterations left: 10
# alpha:
# [ 0.32366841  0.67633159]
# mu:
# [[-0.13221333  1.05756368]
#  [-0.03381978  0.69286777]]
# sigma:
# [[[  2.00781740e-04   5.33278393e-02]
#   [  3.51094639e-04  -1.52753473e-01]]
#
#  [[  3.51094639e-04  -1.52753473e-01]
#   [  1.63459915e-02   6.25911208e-01]]]
# Likelihood: 4.03
# change: 833.59%
# Iterations left: 10
# alpha:
# [ 0.37849426  0.62150574]
# mu:
# [[-0.13381726  1.10810891]
#  [-0.02416326  0.62991446]]
# sigma:
# [[[  1.69521594e-04   5.68923913e-02]
#   [  1.52106592e-04  -1.58930630e-01]]
#
#  [[  1.52106592e-04  -1.58930630e-01]
#   [  2.56154392e-02   6.34334863e-01]]]
# Likelihood: 5.97
# change: 32.53%
# Iterations left: 10
# alpha:
# [ 0.44676159  0.55323841]
# mu:
# [[-0.13671378  1.15488084]
#  [-0.00829336  0.53313709]]
# sigma:
# [[[  1.92742588e-04   6.16176935e-02]
#   [ -5.92366928e-04  -1.64583793e-01]]
#
#  [[ -5.92366928e-04  -1.64583793e-01]
#   [  3.25976406e-02   6.28337597e-01]]]
# Likelihood: 8.18
# ...

# %%
from helperfuncs.PlotScatter2Dhist import PlotScatter2Dhist

PlotScatter2Dhist(TD_meas*1e3, qty_min, 'time diff [msec]', 'quality idx []', ylim_min=0, ylim_max=30, xlim_min=-0.3, xlim_max=0.5)
PlotScatter2Dhist(TD_meas*1e3, np.log10(qty_min), 'time diff [msec]', 'log10(quality idx) []', ylim_min=-1.0, ylim_max=2, xlim_min=-0.3, xlim_max=0.5, fitcurve=True, alpha=alpha_1, mu=mu_1, sigma=sigma_1)
