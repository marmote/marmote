# %% [markdown]
# # Read in preprocessed raw data

# %% [markdown]
# First let's read in the data from BreakTest_AluminiumBeam measurement. Note that the threshold filter has already filtered out the frames with signals in them.

# %%
from helperfuncs.ReadAEMeas import ReadAEMeas

dir = '../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/1-0.5'
y_1, y2_1, T_1, fnames_1, start_time_1 = ReadAEMeas(dir)

dir = '../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/2-0.75'
y_2, y2_2, T_2, fnames_2, start_time_2 = ReadAEMeas(dir)

dir = '../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/3-0.8'
y_3, y2_3, T_3, fnames_3, start_time_3 = ReadAEMeas(dir)

dir = '../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/4-1'
y_4, y2_4, T_4, fnames_4, start_time_4 = ReadAEMeas(dir)

Fs = 1/T_1
#print Fs
# Out:
# Module folder added to system path: /home/ubuntu/Marmote/tools/ControlRecord/ControlRecord
# Opening file: ../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/1-0.5/collect_0.bin
# Closed file: ../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/1-0.5/collect_0.bin
# Opening file: ../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/1-0.5/collect_1.bin
# Closed file: ../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/1-0.5/collect_1.bin
# Opening file: ../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/1-0.5/collect_2.bin
# Closed file: ../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/1-0.5/collect_2.bin
# Opening file: ../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/1-0.5/collect_3.bin
# Closed file: ../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/1-0.5/collect_3.bin
# Opening file: ../../../Measurements/BreakTest_AluminiumBeam/results.enhanced/1-0.5/collect_4.bin
# ...

# %%
import numpy as np

def removeDC(ys):
    for ii in xrange(len(ys)):
        ys[ii] -= np.mean(ys[ii])
    return ys

# %%
y_1 = removeDC(y_1)
y2_1 = removeDC(y2_1)
y_2 = removeDC(y_2)
y2_2 = removeDC(y2_2)
y_3 = removeDC(y_3)
y2_3 = removeDC(y2_3)
y_4 = removeDC(y_4)
y2_4 = removeDC(y2_4)

# %% [markdown]
# # Spectrogram of one measurement

# %%
from helperfuncs.PlotSpecgram import PlotSpecgram

y = y2_1[3]

PlotSpecgram(y, Fs)

# %% [markdown]
# # Time Difference of Arrival (TDOA)

# %% [markdown]
# Theoretical value of TD.

# %%
v = 3909.49 #m/s - sound speed in aluminium
dist_diff = 33*0.0254 #m - distance difference of sensors

TD = dist_diff/v #s - theoretical TD
print 'Theoretical time difference: %.2f us' % (TD*1000000)
print 'Distance traveled in 810.7 usec: %.2f m' % (810.7e-6*v)
print 'Distance traveled in 213 usec: %.2f m' % (213e-6*v)
print 'Distance traveled in 500 usec: %.2f m' % (500e-6*v)
# Out:
# Theoretical time difference: 214.40 us
# Distance traveled in 810.7 usec: 3.17 m
# Distance traveled in 213 usec: 0.83 m
# Distance traveled in 500 usec: 1.95 m

# %% [markdown]
# ## Simple threshold

# %% [markdown]
# Calculate TDOA with simple threshold crossing method.

# %%
from helperfuncs.CalculateTDOA_threshold_method import CalculateTDOA_threshold_method

AE_start_th1, AE_start2_th1, TD_meas_th1 = CalculateTDOA_threshold_method(y_1, y2_1, T_1)
AE_start_th2, AE_start2_th2, TD_meas_th2 = CalculateTDOA_threshold_method(y_2, y2_2, T_2)
AE_start_th3, AE_start2_th3, TD_meas_th3 = CalculateTDOA_threshold_method(y_3, y2_3, T_3)
AE_start_th4, AE_start2_th4, TD_meas_th4 = CalculateTDOA_threshold_method(y_4, y2_4, T_4)

# %% [markdown]
# Plot AE data in separate axes.

# %%
from helperfuncs.PlotAEMeas import PlotAEMeas

PlotAEMeas(y_1,   y2_1,   AE_start_th1,   AE_start2_th1,   T_1)

# %%
from helperfuncs.PlotTDHist import PlotTDHist

PlotTDHist(TD_meas_th1*1e3, fitcurve=True, Gauss_num=2)
# Out:
# Iterations left: 10
# alpha: 0.92, 0.08,
# mu: -0.11, 0.50,
# sigma: 0.15, 0.30,
# Likelihood: 39.91
# change: 573.15%
# Iterations left: 10
# alpha: 0.92, 0.08,
# mu: -0.10, 0.50,
# sigma: 0.15, 0.33,
# Likelihood: 40.64
# change: 1.79%
# Iterations left: 10
# alpha: 0.93, 0.07,
# mu: -0.10, 0.52,
# sigma: 0.16, 0.34,
# Likelihood: 40.86
# change: 0.53%

# %%
from helperfuncs.PlotTDHist import PlotTDHist

PlotTDHist(TD_meas_th2*1e3, fitcurve=True, Gauss_num=2)
# Out:
# Iterations left: 10
# alpha: 0.92, 0.08,
# mu: -0.13, 0.71,
# sigma: 0.13, 0.23,
# Likelihood: 60.95
# change: 325.01%
# Iterations left: 10
# alpha: 0.93, 0.07,
# mu: -0.13, 0.77,
# sigma: 0.13, 0.12,
# Likelihood: 67.56
# change: 9.78%
# Iterations left: 10
# alpha: 0.93, 0.07,
# mu: -0.13, 0.78,
# sigma: 0.13, 0.09,
# Likelihood: 68.53
# change: 1.41%
# Iterations left: 10
# alpha: 0.93, 0.07,
# mu: -0.13, 0.78,
# sigma: 0.13, 0.09,
# Likelihood: 68.53
# change: 0.00%

# %%
from helperfuncs.PlotTDHist import PlotTDHist

PlotTDHist(TD_meas_th3*1e3, fitcurve=True, Gauss_num=2)
# Out:
# Iterations left: 10
# alpha: 0.83, 0.17,
# mu: -0.14, 0.39,
# sigma: 0.14, 0.38,
# Likelihood: 35.33
# change: 1758.74%
# Iterations left: 10
# alpha: 0.86, 0.14,
# mu: -0.13, 0.40,
# sigma: 0.12, 0.48,
# Likelihood: 39.46
# change: 10.46%
# Iterations left: 10
# alpha: 0.87, 0.13,
# mu: -0.13, 0.41,
# sigma: 0.12, 0.49,
# Likelihood: 39.54
# change: 0.20%

# %%
from helperfuncs.PlotTDHist import PlotTDHist

PlotTDHist(TD_meas_th4*1e3, fitcurve=True, Gauss_num=2)
# Out:
# Iterations left: 10
# alpha: 0.85, 0.15,
# mu: -0.08, 0.76,
# sigma: 0.13, 0.18,
# Likelihood: 84.48
# change: 666.97%
# Iterations left: 10
# alpha: 0.85, 0.15,
# mu: -0.08, 0.77,
# sigma: 0.13, 0.15,
# Likelihood: 89.84
# change: 5.97%
# Iterations left: 10
# alpha: 0.85, 0.15,
# mu: -0.08, 0.78,
# sigma: 0.13, 0.13,
# Likelihood: 91.37
# change: 1.67%
# Iterations left: 10
# alpha: 0.85, 0.15,
# mu: -0.08, 0.79,
# sigma: 0.13, 0.12,
# Likelihood: 91.89
# change: 0.57%

# %% [markdown]
# ## Akaike Information Criterion (AIC)

# %% [markdown]
# Calculate TDOA using the Akaike Information Criterion (AIC) as onset picker.

# %%
import matplotlib.pyplot as plt

def plotAICres2D(x, y, xlabel, ylabel, xlim_min=-1, xlim_max=1):
    fig, ax = plt.subplots(1, 1, sharex=True, sharey=True ) 

    ax.scatter(x, y)
    
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_xlim(xlim_min, xlim_max)

# %%
import matplotlib.pyplot as plt

def plotAICres2D_hist(x, y, xlabel, ylabel, xbins=25, ybins=25, xlim_min=-1, xlim_max=1):
    fig, axScatter = plt.subplots(1, 1, sharex=True, sharey=True )

    # the scatter plot:
    axScatter.scatter(x, y)
    #axScatter.set_aspect(1.)

    # create new axes on the right and on the top of the current axes
    # The first argument of the new_vertical(new_horizontal) method is
    # the height (width) of the axes to be created in inches.
    from mpl_toolkits.axes_grid1 import make_axes_locatable
    divider = make_axes_locatable(axScatter)
    axHistx = divider.append_axes("top", 1.2, pad=0.1, sharex=axScatter)
    axHisty = divider.append_axes("right", 1.2, pad=0.1, sharey=axScatter)

    # make some labels invisible
    plt.setp(axHistx.get_xticklabels() + axHisty.get_yticklabels(),
         visible=False)

    axHistx.hist(x, bins=xbins)
    axHisty.hist(y, bins=ybins, orientation='horizontal')

    # the xaxis of axHistx and yaxis of axHisty are shared with axScatter,
    # thus there is no need to manually adjust the xlim and ylim of these
    # axis.

    #axHistx.axis["bottom"].major_ticklabels.set_visible(False)
    for tl in axHistx.get_xticklabels():
        tl.set_visible(False)
    #axHistx.set_yticks([0, 50, 100])

    #axHisty.axis["left"].major_ticklabels.set_visible(False)
    for tl in axHisty.get_yticklabels():
        tl.set_visible(False)
    labels = axHisty.get_xticklabels()
    setp(labels, rotation=90)        
    #axHisty.set_xticks([0, 50, 100])

    axScatter.set_xlim(xlim_min, xlim_max)    
    axHistx.set_xlim( axScatter.get_xlim() )
    axHisty.set_ylim( axScatter.get_ylim() )    
    
    axScatter.set_xlabel(xlabel)
    axScatter.set_ylabel(ylabel)

# %%
import matplotlib.pyplot as plt

def plot_history(qty, TD, qty_th, TD_min, TD_max, start_time, xlim_min, xlim_max, ylim_min, ylim_max):
    fig, ax = plt.subplots(1, 1, sharex=True, sharey=True ) 

    idx = np.intersect1d(np.array(np.where(TD>=TD_min)), np.array(np.where(TD<=TD_max)))
    temp = qty[idx]
    idx2 = np.where(temp>=qty_th)
    
    time = np.array((np.array(start_time)[idx])[idx2]) + np.array((TD[idx])[idx2])
    time -= start_time[0]
    #time /= 60
    ax.plot(time, temp[idx2], '.')
    ax.vlines(time, [0], temp[idx2])
    
#    ax.set_xlabel(xlabel)
#    ax.set_ylabel(ylabel)
    ax.set_xlim(xlim_min, xlim_max)
    ax.set_ylim(ylim_min, ylim_max)

# %% [markdown]
# ### I.

# %%
from helperfuncs.CalculateTDOA_AIC_method import CalculateTDOA_AIC_method

AE_start_1, AE_start2_1, TD_meas_1, qty1, qty21 = CalculateTDOA_AIC_method(y_1, y2_1, T_1)
# Out:
# 0.00%
# 0.54%
# 1.09%
# 1.63%
# 2.17%
# 2.72%
# 3.26%
# 3.80%
# 4.35%
# 4.89%
# 5.43%
# 5.98%
# 6.52%
# 7.07%
# 7.61%
# 8.15%
# 8.70%
# 9.24%
# 9.78%
# 10.33%
# 10.87%
# 11.41%
# 11.96%
# 12.50%
# 13.04%
# 13.59%
# 14.13%
# 14.67%
# 15.22%
# 15.76%
# 16.30%
# 16.85%
# 17.39%
# 17.93%
# 18.48%
# 19.02%
# 19.57%
# 20.11%
# 20.65%
# 21.20%
# 21.74%
# 22.28%
# 22.83%
# 23.37%
# 23.91%
# 24.46%
# 25.00%
# 25.54%
# 26.09%
# 26.63%
# 27.17%
# 27.72%
# 28.26%
# 28.80%
# 29.35%
# 29.89%
# 30.43%
# 30.98%
# 31.52%
# 32.07%
# 32.61%
# 33.15%
# 33.70%
# 34.24%
# 34.78%
# 35.33%
# 35.87%
# 36.41%
# 36.96%
# 37.50%
# 38.04%
# 38.59%
# 39.13%
# 39.67%
# 40.22%
# 40.76%
# 41.30%
# 41.85%
# 42.39%
# 42.93%
# 43.48%
# 44.02%
# 44.57%
# 45.11%
# 45.65%
# 46.20%
# 46.74%
# 47.28%
# 47.83%
# 48.37%
# 48.91%
# 49.46%
# 50.00%
# 50.54%
# 51.09%
# 51.63%
# 52.17%
# 52.72%
# 53.26%
# 53.80%
# 54.35%
# 54.89%
# 55.43%
# 55.98%
# 56.52%
# 57.07%
# 57.61%
# 58.15%
# 58.70%
# 59.24%
# 59.78%
# 60.33%
# 60.87%
# ...

# %%
from helperfuncs.PlotTDHist import PlotTDHist

PlotTDHist(TD_meas_1*1e3, True, -0.5, 1, Gauss_num=2)
# Out:
# Iterations left: 10
# alpha: 0.72, 0.28,
# mu: 0.03, 0.34,
# sigma: 0.13, 0.22,
# Likelihood: 37.30
# change: 1626.48%
# Iterations left: 10
# alpha: 0.75, 0.25,
# mu: 0.05, 0.30,
# sigma: 0.13, 0.28,
# Likelihood: 50.14
# change: 25.62%
# Iterations left: 10
# alpha: 0.77, 0.23,
# mu: 0.07, 0.26,
# sigma: 0.12, 0.34,
# Likelihood: 58.20
# change: 13.84%
# Iterations left: 10
# alpha: 0.79, 0.21,
# mu: 0.08, 0.24,
# sigma: 0.12, 0.38,
# Likelihood: 60.66
# change: 4.07%
# Iterations left: 10
# alpha: 0.81, 0.19,
# mu: 0.09, 0.24,
# sigma: 0.12, 0.40,
# Likelihood: 61.22
# change: 0.91%

# %%
#plotAICres2D(TD_meas_1*1e3, qty21, 'time [msec]', 'quality []')
#plotAICres2D(TD_meas_1*1e3, np.log10(qty21), 'time [msec]', 'log10 quality []')
plotAICres2D_hist(TD_meas_1*1e3, qty21, 'time [msec]', 'quality []')
plotAICres2D_hist(TD_meas_1*1e3, np.log10(qty21), 'time [msec]', 'log10 quality []')

# %%
#From 462.762552 to 953.26476
plot_history(qty21, TD_meas_1, 0, -1, 1, start_time_1, 0, 492, 0, 12)
plot_history(qty21, TD_meas_1, 0.4, 0.16*1e-3, 0.24*1e-3, start_time_1, 0, 492, 0, 12)
plot_history(qty21, TD_meas_1, 0.4, 0.76*1e-3, 0.84*1e-3, start_time_1, 0, 492, 0, 12)

# %%
from helperfuncs.PlotTDHist import PlotTDHist

pickbest = 20
PlotTDHist(TD_meas_1*1e3, True, -0.5, 1, qty21, pickbest=pickbest, Gauss_num=2)
# Out:
# Iterations left: 10
# alpha: 0.59, 0.41,
# mu: 0.18, 0.66,
# sigma: 0.11, 0.27,
# Likelihood: 1.95
# change: 910.03%
# Iterations left: 10
# alpha: 0.64, 0.36,
# mu: 0.18, 0.72,
# sigma: 0.09, 0.26,
# Likelihood: 3.02
# change: 35.50%
# Iterations left: 10
# alpha: 0.66, 0.34,
# mu: 0.19, 0.73,
# sigma: 0.08, 0.28,
# Likelihood: 4.28
# change: 29.29%
# Iterations left: 10
# alpha: 0.64, 0.36,
# mu: 0.20, 0.67,
# sigma: 0.04, 0.35,
# Likelihood: 11.98
# change: 64.29%
# Iterations left: 10
# alpha: 0.63, 0.37,
# mu: 0.21, 0.66,
# sigma: 0.03, 0.36,
# Likelihood: 13.24
# change: 9.57%
# Iterations left: 10
# alpha: 0.61, 0.39,
# mu: 0.21, 0.64,
# sigma: 0.03, 0.36,
# Likelihood: 13.51
# change: 1.98%
# Iterations left: 10
# alpha: 0.60, 0.40,
# mu: 0.21, 0.62,
# sigma: 0.02, 0.37,
# Likelihood: 13.84
# change: 2.34%
# Iterations left: 10
# alpha: 0.59, 0.41,
# mu: 0.21, 0.61,
# sigma: 0.02, 0.37,
# Likelihood: 14.21
# change: 2.63%
# Iterations left: 10
# alpha: 0.58, 0.42,
# ...

# %% [markdown]
# ### II.

# %%
from helperfuncs.CalculateTDOA_AIC_method import CalculateTDOA_AIC_method

AE_start_2, AE_start2_2, TD_meas_2, qty2, qty22 = CalculateTDOA_AIC_method(y_2, y2_2, T_2)
# Out:
# 0.00%
# 0.57%
# 1.14%
# 1.70%
# 2.27%
# 2.84%
# 3.41%
# 3.98%
# 4.55%
# 5.11%
# 5.68%
# 6.25%
# 6.82%
# 7.39%
# 7.95%
# 8.52%
# 9.09%
# 9.66%
# 10.23%
# 10.80%
# 11.36%
# 11.93%
# 12.50%
# 13.07%
# 13.64%
# 14.20%
# 14.77%
# 15.34%
# 15.91%
# 16.48%
# 17.05%
# 17.61%
# 18.18%
# 18.75%
# 19.32%
# 19.89%
# 20.45%
# 21.02%
# 21.59%
# 22.16%
# 22.73%
# 23.30%
# 23.86%
# 24.43%
# 25.00%
# 25.57%
# 26.14%
# 26.70%
# 27.27%
# 27.84%
# 28.41%
# 28.98%
# 29.55%
# 30.11%
# 30.68%
# 31.25%
# 31.82%
# 32.39%
# 32.95%
# 33.52%
# 34.09%
# 34.66%
# 35.23%
# 35.80%
# 36.36%
# 36.93%
# 37.50%
# 38.07%
# 38.64%
# 39.20%
# 39.77%
# 40.34%
# 40.91%
# 41.48%
# 42.05%
# 42.61%
# 43.18%
# 43.75%
# 44.32%
# 44.89%
# 45.45%
# 46.02%
# 46.59%
# 47.16%
# 47.73%
# 48.30%
# 48.86%
# 49.43%
# 50.00%
# 50.57%
# 51.14%
# 51.70%
# 52.27%
# 52.84%
# 53.41%
# 53.98%
# 54.55%
# 55.11%
# 55.68%
# 56.25%
# 56.82%
# 57.39%
# 57.95%
# 58.52%
# 59.09%
# 59.66%
# 60.23%
# 60.80%
# 61.36%
# 61.93%
# 62.50%
# 63.07%
# 63.64%
# ...

# %%
from helperfuncs.PlotTDHist import PlotTDHist

PlotTDHist(TD_meas_2*1e3, True, -0.5, 1, Gauss_num=2)
# Out:
# Iterations left: 10
# alpha: 0.84, 0.16,
# mu: 0.09, 0.53,
# sigma: 0.13, 0.25,
# Likelihood: 46.34
# change: 484.68%
# Iterations left: 10
# alpha: 0.86, 0.14,
# mu: 0.09, 0.55,
# sigma: 0.13, 0.28,
# Likelihood: 47.78
# change: 3.01%
# Iterations left: 10
# alpha: 0.87, 0.13,
# mu: 0.10, 0.57,
# sigma: 0.13, 0.28,
# Likelihood: 48.29
# change: 1.05%
# Iterations left: 10
# alpha: 0.88, 0.12,
# mu: 0.10, 0.60,
# sigma: 0.14, 0.27,
# Likelihood: 48.68
# change: 0.81%

# %%
#plotAICres2D(TD_meas_2*1e3, qty22, 'time [msec]', 'quality []')
#plotAICres2D(TD_meas_2*1e3, np.log10(qty22), 'time [msec]', 'log10 quality []')
plotAICres2D_hist(TD_meas_2*1e3, qty22, 'time [msec]', 'quality []')
plotAICres2D_hist(TD_meas_2*1e3, np.log10(qty22), 'time [msec]', 'log10 quality []')

# %%
#From 1300.786704 to 1486.019976
plot_history(qty22, TD_meas_2, 0, -1, 1, start_time_2, 0, 187, 0, 9)
plot_history(qty22, TD_meas_2, 0.5, 0.16*1e-3, 0.24*1e-3, start_time_2, 0, 187, 0, 9)
plot_history(qty22, TD_meas_2, 0.5, 0.76*1e-3, 0.84*1e-3, start_time_2, 0, 187, 0, 9)

# %%
from helperfuncs.PlotTDHist import PlotTDHist

pickbest = 20
PlotTDHist(TD_meas_2*1e3, True, -0.5, 1, qty22, pickbest=pickbest, Gauss_num=2)
# Out:
# Iterations left: 10
# alpha: 0.28, 0.72,
# mu: 0.14, 0.74,
# sigma: 0.21, 0.17,
# Likelihood: -0.05
# change: 22541.32%
# Iterations left: 10
# alpha: 0.31, 0.69,
# mu: 0.14, 0.77,
# sigma: 0.18, 0.11,
# Likelihood: 4.49
# change: 101.17%
# Iterations left: 10
# alpha: 0.35, 0.65,
# mu: 0.16, 0.80,
# sigma: 0.18, 0.06,
# Likelihood: 9.39
# change: 52.17%
# Iterations left: 10
# alpha: 0.36, 0.64,
# mu: 0.18, 0.80,
# sigma: 0.20, 0.05,
# Likelihood: 11.22
# change: 16.29%
# Iterations left: 10
# alpha: 0.40, 0.60,
# mu: 0.22, 0.81,
# sigma: 0.23, 0.03,
# Likelihood: 16.39
# change: 31.56%
# Iterations left: 10
# alpha: 0.40, 0.60,
# mu: 0.22, 0.81,
# sigma: 0.23, 0.02,
# Likelihood: 16.99
# change: 3.51%
# Iterations left: 10
# alpha: 0.40, 0.60,
# mu: 0.22, 0.81,
# sigma: 0.23, 0.02,
# Likelihood: 16.99
# change: 0.00%

# %% [markdown]
# ### III.

# %%
from helperfuncs.CalculateTDOA_AIC_method import CalculateTDOA_AIC_method

AE_start_3, AE_start2_3, TD_meas_3, qty3, qty23 = CalculateTDOA_AIC_method(y_3, y2_3, T_3)
# Out:
# 0.00%
# 0.61%
# 1.22%
# 1.83%
# 2.44%
# 3.05%
# 3.66%
# 4.27%
# 4.88%
# 5.49%
# 6.10%
# 6.71%
# 7.32%
# 7.93%
# 8.54%
# 9.15%
# 9.76%
# 10.37%
# 10.98%
# 11.59%
# 12.20%
# 12.80%
# 13.41%
# 14.02%
# 14.63%
# 15.24%
# 15.85%
# 16.46%
# 17.07%
# 17.68%
# 18.29%
# 18.90%
# 19.51%
# 20.12%
# 20.73%
# 21.34%
# 21.95%
# 22.56%
# 23.17%
# 23.78%
# 24.39%
# 25.00%
# 25.61%
# 26.22%
# 26.83%
# 27.44%
# 28.05%
# 28.66%
# 29.27%
# 29.88%
# 30.49%
# 31.10%
# 31.71%
# 32.32%
# 32.93%
# 33.54%
# 34.15%
# 34.76%
# 35.37%
# 35.98%
# 36.59%
# 37.20%
# 37.80%
# 38.41%
# 39.02%
# 39.63%
# 40.24%
# 40.85%
# 41.46%
# 42.07%
# 42.68%
# 43.29%
# 43.90%
# 44.51%
# 45.12%
# 45.73%
# 46.34%
# 46.95%
# 47.56%
# 48.17%
# 48.78%
# 49.39%
# 50.00%
# 50.61%
# 51.22%
# 51.83%
# 52.44%
# 53.05%
# 53.66%
# 54.27%
# 54.88%
# 55.49%
# 56.10%
# 56.71%
# 57.32%
# 57.93%
# 58.54%
# 59.15%
# 59.76%
# 60.37%
# 60.98%
# 61.59%
# 62.20%
# 62.80%
# 63.41%
# 64.02%
# 64.63%
# 65.24%
# 65.85%
# 66.46%
# 67.07%
# 67.68%
# 68.29%
# ...

# %%
from helperfuncs.PlotTDHist import PlotTDHist

PlotTDHist(TD_meas_3*1e3, True, -0.5, 1, Gauss_num=2)
# Out:
# Iterations left: 10
# alpha: 0.51, 0.49,
# mu: -0.00, 0.29,
# sigma: 0.12, 0.22,
# Likelihood: 10.58
# change: 5762.40%
# Iterations left: 10
# alpha: 0.52, 0.48,
# mu: 0.04, 0.26,
# sigma: 0.12, 0.26,
# Likelihood: 24.37
# change: 56.59%
# Iterations left: 10
# alpha: 0.55, 0.45,
# mu: 0.06, 0.24,
# sigma: 0.12, 0.29,
# Likelihood: 30.09
# change: 18.99%
# Iterations left: 10
# alpha: 0.59, 0.41,
# mu: 0.08, 0.24,
# sigma: 0.11, 0.31,
# Likelihood: 33.32
# change: 9.71%
# Iterations left: 10
# alpha: 0.63, 0.37,
# mu: 0.09, 0.24,
# sigma: 0.12, 0.33,
# Likelihood: 35.44
# change: 5.97%
# Iterations left: 10
# alpha: 0.67, 0.33,
# mu: 0.10, 0.24,
# sigma: 0.12, 0.34,
# Likelihood: 36.96
# change: 4.11%
# Iterations left: 10
# alpha: 0.70, 0.30,
# mu: 0.10, 0.25,
# sigma: 0.12, 0.36,
# Likelihood: 38.10
# change: 3.00%
# Iterations left: 10
# alpha: 0.73, 0.27,
# mu: 0.10, 0.26,
# sigma: 0.12, 0.37,
# Likelihood: 38.97
# change: 2.22%
# Iterations left: 10
# alpha: 0.75, 0.25,
# ...

# %%
#plotAICres2D(TD_meas_3*1e3, qty23, 'time [msec]', 'quality []')
#plotAICres2D(TD_meas_3*1e3, np.log10(qty23), 'time [msec]', 'log10 quality []')
plotAICres2D_hist(TD_meas_3*1e3, qty23, 'time [msec]', 'quality []')
plotAICres2D_hist(TD_meas_3*1e3, np.log10(qty23), 'time [msec]', 'log10 quality []')

# %%
#From 1607.045832 to 2150.706936
plot_history(qty23, TD_meas_3, 0, -1, 1, start_time_3, 0, 544, 0, 8)
plot_history(qty23, TD_meas_3, 0.5, 0.16*1e-3, 0.24*1e-3, start_time_3, 0, 544, 0, 8)
plot_history(qty23, TD_meas_3, 0.5, 0.76*1e-3, 0.84*1e-3, start_time_3, 0, 544, 0, 8)

# %%
from helperfuncs.PlotTDHist import PlotTDHist

pickbest = 20
PlotTDHist(TD_meas_3*1e3, True, -0.5, 1, qty23, pickbest=pickbest, Gauss_num=2)
# Out:
# Iterations left: 10
# alpha: 0.31, 0.69,
# mu: -0.11, 0.65,
# sigma: 0.29, 0.30,
# Likelihood: -11.19
# change: 90.89%
# Iterations left: 10
# alpha: 0.34, 0.66,
# mu: -0.10, 0.68,
# sigma: 0.28, 0.27,
# Likelihood: -10.66
# change: 5.01%
# Iterations left: 10
# alpha: 0.38, 0.62,
# mu: -0.08, 0.72,
# sigma: 0.27, 0.24,
# Likelihood: -9.66
# change: 10.38%
# Iterations left: 10
# alpha: 0.42, 0.58,
# mu: -0.06, 0.76,
# sigma: 0.27, 0.18,
# Likelihood: -7.31
# change: 32.14%
# Iterations left: 10
# alpha: 0.46, 0.54,
# mu: -0.04, 0.80,
# sigma: 0.27, 0.11,
# Likelihood: -3.17
# change: 130.91%
# Iterations left: 10
# alpha: 0.49, 0.51,
# mu: -0.00, 0.82,
# sigma: 0.29, 0.05,
# Likelihood: 3.51
# change: 190.28%
# Iterations left: 10
# alpha: 0.50, 0.50,
# mu: 0.01, 0.83,
# sigma: 0.29, 0.02,
# Likelihood: 7.21
# change: 51.36%
# Iterations left: 10
# alpha: 0.50, 0.50,
# mu: 0.01, 0.83,
# sigma: 0.29, 0.02,
# Likelihood: 7.21
# change: 0.00%

# %% [markdown]
# ### IV.

# %%
from helperfuncs.CalculateTDOA_AIC_method import CalculateTDOA_AIC_method

AE_start_4, AE_start2_4, TD_meas_4, qty4, qty24 = CalculateTDOA_AIC_method(y_4, y2_4, T_4)
# Out:
# 0.00%
# 0.21%
# 0.43%
# 0.64%
# 0.86%
# 1.07%
# 1.28%
# 1.50%
# 1.71%
# 1.93%
# 2.14%
# 2.36%
# 2.57%
# 2.78%
# 3.00%
# 3.21%
# 3.43%
# 3.64%
# 3.85%
# 4.07%
# 4.28%
# 4.50%
# 4.71%
# 4.93%
# 5.14%
# 5.35%
# 5.57%
# 5.78%
# 6.00%
# 6.21%
# 6.42%
# 6.64%
# 6.85%
# 7.07%
# 7.28%
# 7.49%
# 7.71%
# 7.92%
# 8.14%
# 8.35%
# 8.57%
# 8.78%
# 8.99%
# 9.21%
# 9.42%
# 9.64%
# 9.85%
# 10.06%
# 10.28%
# 10.49%
# 10.71%
# 10.92%
# 11.13%
# 11.35%
# 11.56%
# 11.78%
# 11.99%
# 12.21%
# 12.42%
# 12.63%
# 12.85%
# 13.06%
# 13.28%
# 13.49%
# 13.70%
# 13.92%
# 14.13%
# 14.35%
# 14.56%
# 14.78%
# 14.99%
# 15.20%
# 15.42%
# 15.63%
# 15.85%
# 16.06%
# 16.27%
# 16.49%
# 16.70%
# 16.92%
# 17.13%
# 17.34%
# 17.56%
# 17.77%
# 17.99%
# 18.20%
# 18.42%
# 18.63%
# 18.84%
# 19.06%
# 19.27%
# 19.49%
# 19.70%
# 19.91%
# 20.13%
# 20.34%
# 20.56%
# 20.77%
# 20.99%
# 21.20%
# 21.41%
# 21.63%
# 21.84%
# 22.06%
# 22.27%
# 22.48%
# 22.70%
# 22.91%
# 23.13%
# 23.34%
# 23.55%
# 23.77%
# 23.98%
# 24.20%
# 24.41%
# 24.63%
# ...

# %%
from helperfuncs.PlotTDHist import PlotTDHist

PlotTDHist(TD_meas_4*1e3, False, -0.5, 1, Gauss_num=2)

# %%
#plotAICres2D(TD_meas_4*1e3, qty24, 'time [msec]', 'quality []')
#plotAICres2D(TD_meas_4*1e3, np.log10(qty24), 'time [msec]', 'log10 quality []')
plotAICres2D_hist(TD_meas_4*1e3, qty24, 'time [msec]', 'quality []')
plotAICres2D_hist(TD_meas_4*1e3, np.log10(qty24), 'time [msec]', 'log10 quality []')

# %%
#From 2336.045376 to 3350.14512
plot_history(qty24, TD_meas_4, 0, -1, 1, start_time_4, 0, 1014, 0, 20)
plot_history(qty24, TD_meas_4, 0.5, 0.16*1e-3, 0.24*1e-3, start_time_4, 0, 1014, 0, 20)
plot_history(qty24, TD_meas_4, 0.5, 0.76*1e-3, 0.84*1e-3, start_time_4, 0, 1014, 0, 20)

# %%
from helperfuncs.PlotTDHist import PlotTDHist

pickbest = 20
PlotTDHist(TD_meas_4*1e3, False, -0.5, 1, qty24, pickbest=pickbest, Gauss_num=2)

# %% [markdown]
# ### Closer look

# %%
from helperfuncs.Onset_AIC import Onset_AIC

ym = y_1[np.argsort(qty21)[-1]]
onset, AIC = Onset_AIC(ym, T_1*1e3)

t_y = arange(ym.size)*T_1*1e3
t_AIC = arange(AIC.size)*T_1*1e3
t_dAIC = arange(AIC.size-1)*T_1*1e3

dAIC = []
for ii in xrange(AIC.size-1):
    dAIC.append(AIC[ii+1] - AIC[ii])

fig, axarr = plt.subplots(3, 1, sharex=True)
axarr = axarr.flat
axarr[0].plot(t_y, ym, 'b', [onset, onset], [np.amin(ym), np.amax(ym)] , 'r')
axarr[1].plot(t_AIC, AIC, 'b', [onset, onset], [np.amin(AIC), np.amax(AIC)], 'r')
axarr[2].plot(t_dAIC, dAIC, 'b', [onset, onset], [np.amin(dAIC), np.amax(dAIC)], 'r')
axarr[2].set_ylim(-10, 10)
#axarr[2].set_xlim(onset-20, onset+20)
# Out:
# (-10, 10)

# %%
from helperfuncs.Onset_AIC import Onset_AIC

ym = y2_1[np.argsort(qty21)[-1]]
onset, AIC = Onset_AIC(ym, T_1*1e3)

t_y = arange(ym.size)*T_1*1e3
t_AIC = arange(AIC.size)*T_1*1e3
t_dAIC = arange(AIC.size-1)*T_1*1e3

dAIC = []
for ii in xrange(AIC.size-1):
    dAIC.append(AIC[ii+1] - AIC[ii])

fig, axarr = plt.subplots(3, 1, sharex=True)
axarr = axarr.flat
axarr[0].plot(t_y, ym, 'b', [onset, onset], [np.amin(ym), np.amax(ym)] , 'r')
axarr[1].plot(t_AIC, AIC, 'b', [onset, onset], [np.amin(AIC), np.amax(AIC)], 'r')
axarr[2].plot(t_dAIC, dAIC, 'b', [onset, onset], [np.amin(dAIC), np.amax(dAIC)], 'r')
axarr[2].set_ylim(-10, 10)
#axarr[2].set_xlim(onset-20, onset+20)
# Out:
# (-10, 10)

# %%
from helperfuncs.Onset_AIC import Onset_AIC

ym = y_1[np.argsort(qty21)[-4]]
onset, AIC = Onset_AIC(ym, T_1*1e3)

t_y = arange(ym.size)*T_1*1e3
t_AIC = arange(AIC.size)*T_1*1e3
t_dAIC = arange(AIC.size-1)*T_1*1e3

dAIC = []
for ii in xrange(AIC.size-1):
    dAIC.append(AIC[ii+1] - AIC[ii])

fig, axarr = plt.subplots(3, 1, sharex=True)
axarr = axarr.flat
axarr[0].plot(t_y, ym, 'b', [onset, onset], [np.amin(ym), np.amax(ym)] , 'r')
axarr[1].plot(t_AIC, AIC, 'b', [onset, onset], [np.amin(AIC), np.amax(AIC)], 'r')
axarr[2].plot(t_dAIC, dAIC, 'b', [onset, onset], [np.amin(dAIC), np.amax(dAIC)], 'r')
axarr[2].set_ylim(-10, 10)
#axarr[2].set_xlim(onset-20, onset+20)
# Out:
# (-10, 10)

# %%
from helperfuncs.Onset_AIC import Onset_AIC

ym = y2_1[np.argsort(qty21)[-4]]
onset, AIC = Onset_AIC(ym, T_1*1e3)

t_y = arange(ym.size)*T_1*1e3
t_AIC = arange(AIC.size)*T_1*1e3
t_dAIC = arange(AIC.size-1)*T_1*1e3

dAIC = []
for ii in xrange(AIC.size-1):
    dAIC.append(AIC[ii+1] - AIC[ii])

fig, axarr = plt.subplots(3, 1, sharex=True)
axarr = axarr.flat
axarr[0].plot(t_y, ym, 'b', [onset, onset], [np.amin(ym), np.amax(ym)] , 'r')
axarr[1].plot(t_AIC, AIC, 'b', [onset, onset], [np.amin(AIC), np.amax(AIC)], 'r')
axarr[2].plot(t_dAIC, dAIC, 'b', [onset, onset], [np.amin(dAIC), np.amax(dAIC)], 'r')
axarr[2].set_ylim(-10, 10)
#axarr[2].set_xlim(onset-20, onset+20)
# Out:
# (-10, 10)
